# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

imagen = cv2.imread('biologia.jpg', cv2.IMREAD_COLOR)
imagenRGB = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
cv2.imwrite('biologia.jpg', imagenRGB)
copia = imagenRGB.copy()

# %%
imagen.shape
# Out:
# (794, 1200, 3)

# %%
sueño = imagenRGB[225:505,400:710]
sueño.shape
# Out:
# (280, 310, 3)

# %%
black = np.where

# %%
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
plt.title('Imagen Original')
plt.imshow(imagenRGB)
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('recortar')
plt.imshow(sueño)
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('añadiendo')
plt.imshow(copia)
plt.axis('off')


plt.tight_layout()
plt.show()
